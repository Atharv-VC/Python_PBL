# %%
import pandas as pd

# %%
df=pd.read_csv("D:\ML Project\Sample Datasets\dirty_agriculture_dataset.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\yogesh kumar\AppData\Local\Temp\ipykernel_17836\2674629622.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df=pd.read_csv("D:\ML Project\Sample Datasets\dirty_agriculture_dataset.csv")

# %%
df.isna().sum()
# Out:
# Unnamed: 0                         2202
# Year                                  0
# State Name                            0
# Dist Name                             0
# Area_ha                            2236
# Crop_Area_ha                       2196
# Fertilizer_Usage_kg_per_hectare    2207
# Groundwater_Level_m                2167
# Historical_Yield_Variance          2211
# Humidity_%                         2182
# K_req_kg_per_ha                    2135
# N_req_kg_per_ha                    2194
# P_req_kg_per_ha                    2160
# Rainfall_mm                        2215
# Temperature_C                      2170
# Total_Area_ha                      2143
# Total_Irrigation(1000 ha)          2238
# Total_K_kg                         2245
# Total_N_kg                         2245
# Total_P_kg                         2098
# Total_Yield_t_per_ha               2192
# Wind_Speed_m_s                     2170
# Yield_kg_per_ha                    2107
# ...
