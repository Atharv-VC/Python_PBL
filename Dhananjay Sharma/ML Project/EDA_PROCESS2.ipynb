# %%
import pandas as pd

# %%
df=pd.read_csv("D:\ML Project\Sample Datasets\ICRISAT-District Level Data (2).csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\yogesh kumar\AppData\Local\Temp\ipykernel_111684\2648899271.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df=pd.read_csv("D:\ML Project\Sample Datasets\ICRISAT-District Level Data (2).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16047 entries, 0 to 16046
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Dist Code                            16047 non-null  int64
#  1   Year                                 16047 non-null  int64
#  2   State Code                           16047 non-null  int64
#  3   State Name                           16047 non-null  object
#  4   Dist Name                            16047 non-null  object
#  5   NITROGEN CONSUMPTION (tons)          16047 non-null  float64
#  6   NITROGEN SHARE IN NPK (Percent)      16047 non-null  float64
#  7   NITROGEN PER HA OF NCA (Kg per ha)   16047 non-null  float64
#  8   NITROGEN PER HA OF GCA (Kg per ha)   16047 non-null  float64
#  9   PHOSPHATE CONSUMPTION (tons)         16047 non-null  float64
#  10  PHOSPHATE SHARE IN NPK (Percent)     16047 non-null  float64
# ...

# %%
df.head()
# Out:
#    Dist Code  Year  State Code    State Name Dist Name  \
# 0          1  1966          14  Chhattisgarh      Durg
# 1          1  1967          14  Chhattisgarh      Durg
# 2          1  1968          14  Chhattisgarh      Durg
# 3          1  1969          14  Chhattisgarh      Durg
# 4          1  1970          14  Chhattisgarh      Durg
#
#    NITROGEN CONSUMPTION (tons)  NITROGEN SHARE IN NPK (Percent)  \
# 0                       1375.0                            80.74
# 1                       1516.0                            78.79
# 2                       3042.0                            85.84
# 3                       4131.0                            82.39
# 4                       4594.0                            67.92
#
#    NITROGEN PER HA OF NCA (Kg per ha)  NITROGEN PER HA OF GCA (Kg per ha)  \
# 0                                1.38                                1.27
# 1                                1.50                                1.17
# ...

# %%
# 1. Identify the columns you want by name
id_cols = ['Year', 'State Name', 'Dist Name']

# 2. Grab the last 4 columns dynamically using iloc
last_4_cols = df.columns[-4:].tolist()

# 3. Combine and filter the DataFrame
df_final = df[id_cols + last_4_cols]

# Check the result
df_final.head()
# Out:
#    Year    State Name Dist Name  soil_moisture_level_percent  \
# 0  1966  Chhattisgarh      Durg                    31.476999
# 1  1966  Chhattisgarh      Durg                    27.032150
# 2  1966  Chhattisgarh      Durg                    32.533820
# 3  1967  Chhattisgarh      Durg                    38.661209
# 4  1967  Chhattisgarh      Durg                    26.360926
#
#    pesticide_usage_kg_per_hectare  altitude_meters  \
# 0                        2.604451       296.574626
# 1                        2.999402        10.000000
# 2                        1.837156       302.155906
# 3                        1.635120       340.220755
# 4                        1.091924       244.109476
#
#    farming_mechanization_score
# 0                    65.062861
# 1                    34.360686
# 2                    74.779958
# 3                    67.209165
# 4                    44.357385

# %%
df_final.to_csv("features.csv")
