# %%
import pandas as pd

# %%
df1=pd.read_csv("D:\ML Project\Sample Datasets\Custom_Crops_yield_Historical_Dataset.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\yogesh kumar\AppData\Local\Temp\ipykernel_51912\419399030.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df1=pd.read_csv("D:\ML Project\Sample Datasets\Custom_Crops_yield_Historical_Dataset.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50765 entries, 0 to 50764
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Dist Code                  50765 non-null  int64
#  1   Year                       50765 non-null  int64
#  2   State Code                 50765 non-null  int64
#  3   State Name                 50765 non-null  object
#  4   Dist Name                  50765 non-null  object
#  5   Crop                       50765 non-null  object
#  6   Area_ha                    50765 non-null  float64
#  7   Yield_kg_per_ha            50765 non-null  float64
#  8   N_req_kg_per_ha            50765 non-null  float64
#  9   P_req_kg_per_ha            50765 non-null  float64
#  10  K_req_kg_per_ha            50765 non-null  float64
#  11  Total_N_kg                 50765 non-null  float64
#  12  Total_P_kg                 50765 non-null  float64
# ...

# %%
df1.sample(10)
# Out:
#        Dist Code  Year  State Code      State Name             Dist Name  \
# 39740        242  2008          16     Uttarakhand         Tehri Garhwal
# 13437         76  1979           5       Karnataka  Bijapur / Vijayapura
# 35242        210  1992          12   Uttar Pradesh             Allahabad
# 18406        106  2013           7     Maharashtra               Solapur
# 23481        134  1978           3         Gujarat            Panchmahal
# 28463        164  2015          10       Rajasthan               Udaipur
# 21737        124  1971           3         Gujarat               Bharuch
# 19885        114  1978           7     Maharashtra                 Akola
# 21924        125  1966           3         Gujarat     Vadodara / Baroda
# 5446          34  1977           6  Madhya Pradesh                Jhabua
#
#            Crop   Area_ha  Yield_kg_per_ha  N_req_kg_per_ha  P_req_kg_per_ha  \
# 39740     maize    2040.0          1024.51         27.66177         12.29412
# ...

# %%
df1=df1.drop(columns=['Dist Code', 'State Code'])

# %%
df1.sample(10)
# Out:
#        Year      State Name                      Dist Name      Crop  \
# 27676  1979       Rajasthan                 Swami Madhopur     maize
# 33482  1982   Uttar Pradesh                       Bareilly  chickpea
# 39052  1990   Uttar Pradesh                      Barabanki      rice
# 13281  1992       Karnataka                        Belgaum      rice
# 34952  2000   Uttar Pradesh                         Kanpur      rice
# 1159   1973  Madhya Pradesh                       Balaghat     maize
# 41340  1987           Assam  North Cachar Hil / Dima hasao      rice
# 17084  1989     Maharashtra                          Dhule  chickpea
# 19800  2005     Maharashtra                       Buldhana     maize
# 50655  1977       Jharkhand                      Singhbhum     maize
#
#         Area_ha  Yield_kg_per_ha  N_req_kg_per_ha  P_req_kg_per_ha  \
# 27676    6000.0           466.67         12.60009          5.60004
# 33482   13100.0           793.89         14.29002          7.93890
# ...

# %%
df1.head(30)
# Out:
#     Year    State Name Dist Name      Crop   Area_ha  Yield_kg_per_ha  \
# 0   1966  Chhattisgarh      Durg      rice  548000.0           337.59
# 1   1966  Chhattisgarh      Durg     maize    3000.0           666.67
# 2   1966  Chhattisgarh      Durg  chickpea   54000.0           500.00
# 3   1967  Chhattisgarh      Durg      rice  547000.0           747.71
# 4   1967  Chhattisgarh      Durg     maize    3000.0          1000.00
# 5   1967  Chhattisgarh      Durg  chickpea   52000.0           288.46
# 6   1968  Chhattisgarh      Durg      rice  556300.0           841.27
# 7   1968  Chhattisgarh      Durg     maize    2800.0           714.29
# 8   1968  Chhattisgarh      Durg  chickpea   51300.0           448.34
# 9   1969  Chhattisgarh      Durg      rice  563400.0           711.40
# 10  1969  Chhattisgarh      Durg     maize    2700.0           851.85
# 11  1969  Chhattisgarh      Durg  chickpea   52600.0           439.16
# ...

# %%
df1 = df1.groupby(['Year', 'State Name', 'Dist Name'], as_index=False).mean(numeric_only=True)

# %%
df1.head(30)
# Out:
#     Year      State Name                                Dist Name  \
# 0   1966  Andhra Pradesh                               Ananthapur
# 1   1966  Andhra Pradesh                                 Chittoor
# 2   1966  Andhra Pradesh                            East Godavari
# 3   1966  Andhra Pradesh                                   Guntur
# 4   1966  Andhra Pradesh                               Kadapa YSR
# 5   1966  Andhra Pradesh                                  Krishna
# 6   1966  Andhra Pradesh                                  Kurnool
# 7   1966  Andhra Pradesh                           S.P.S. Nellore
# 8   1966  Andhra Pradesh                               Srikakulam
# 9   1966  Andhra Pradesh                            Visakhapatnam
# 10  1966  Andhra Pradesh                            West Godavari
# 11  1966           Assam                                   Cachar
# 12  1966           Assam                                  Darrang
# ...

# %%
df1.describe()
# Out:
#                Year        Area_ha  Yield_kg_per_ha  N_req_kg_per_ha  \
# count  15972.000000   15972.000000     15972.000000     15972.000000
# mean    1991.659216   64995.435136      1204.539305        29.682653
# std       14.963793   55235.023521       661.368072        16.801349
# min     1966.000000      10.000000         8.000000         0.144000
# 25%     1979.000000   26148.750000       754.305000        18.156863
# 50%     1992.000000   50435.000000      1063.396667        25.894619
# 75%     2005.000000   87335.416667      1503.188125        37.181250
# max     2017.000000  553755.000000     20280.966667       372.292307
#
#        P_req_kg_per_ha  K_req_kg_per_ha    Total_N_kg    Total_P_kg  \
# count     15972.000000     15972.000000  1.597200e+04  1.597200e+04
# mean         14.059965        23.694151  2.342014e+06  1.119942e+06
# std           7.846941        13.164703  2.821599e+06  1.346741e+06
# min           0.080000         0.144000  4.589460e+01  2.039760e+01
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15972 entries, 0 to 15971
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       15972 non-null  int64
#  1   State Name                 15972 non-null  object
#  2   Dist Name                  15972 non-null  object
#  3   Area_ha                    15972 non-null  float64
#  4   Yield_kg_per_ha            15972 non-null  float64
#  5   N_req_kg_per_ha            15972 non-null  float64
#  6   P_req_kg_per_ha            15972 non-null  float64
#  7   K_req_kg_per_ha            15972 non-null  float64
#  8   Total_N_kg                 15972 non-null  float64
#  9   Total_P_kg                 15972 non-null  float64
#  10  Total_K_kg                 15972 non-null  float64
#  11  Temperature_C              15972 non-null  float64
#  12  Humidity_%                 15972 non-null  float64
# ...

# %%
df1.columns.to_list()
# Out:
# ['Year',
#  'State Name',
#  'Dist Name',
#  'Area_ha',
#  'Yield_kg_per_ha',
#  'N_req_kg_per_ha',
#  'P_req_kg_per_ha',
#  'K_req_kg_per_ha',
#  'Total_N_kg',
#  'Total_P_kg',
#  'Total_K_kg',
#  'Temperature_C',
#  'Humidity_%',
#  'pH',
#  'Rainfall_mm',
#  'Wind_Speed_m_s',
#  'Solar_Radiation_MJ_m2_day']

# %%
df1.to_csv("features2.csv")
